# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv
# %matplotlib inline

# %%
#Read CSV
with open('C:/Users/Imtiyaz/Desktop/Inernational_student_Dataset/Students Enrolled in and Entrants to Third Level Courses by institution+year.csv', "r") as f:
    reader = csv.reader(f)
    csv = []
    for column in reader:
        csv.append(column)

# %%
print(csv)
# Out:
# [['Students Enrolled in and Entrants to Third Level Courses by', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['Institution, statistical indicator and Year', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], [' ', ' ', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017'], ['Aided university sector', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], [' ', 'Full-time Enrolments to Third Level Courses (Number)', '..', '..', '..', '..', '..', '..', '..', '..', '78577', '82298', '87623', '89273', '89928', '90341', '93023', '95120', '100793', '105051'], [' ', 'Part-time Enrolments to Third Level Courses (Number)', '..', '..', '..', '..', '..', '..', '..', '..', '14647', '14703', '13936', '13915', '15767', '16834', '15547', '15655', '15
# ...

# %%
#view full dataset
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#convert list into dataframe
Institute = pd.DataFrame(csv)

# %%
Institute
# Out:
#                                                      0  \
# 0    Students Enrolled in and Entrants to Third Lev...
# 1          Institution, statistical indicator and Year
# 2
# 3
# 4                              Aided university sector
# 5
# 6
# 7
# 8                 National University of Ireland, Cork
# 9
# 10
# 11
# 12              National University of Ireland, Dublin
# 13
# 14
# 15
# 16              National University of Ireland, Galway
# 17
# 18
# 19
# 20                             Trinity College, Dublin
# 21
# 22
# 23
# 24            National University of Ireland, Maynooth
# 25
# 26
# 27
# 28                              Dublin City University
# 29
# 30
# 31
# 32                              University of Limerick
# 33
# 34
# 35
# 36                             Aided technology sector
# 37
# 38
# 39
# 40                      Dublin Institute of Technology
# 41
# 42
# 43
# 44                     Athlone Institute of Technology
# 45
# 46
# 47
# ...

# %%
# Delete rows with index label   
Institute_Final= Institute.drop(Institute.index[:4])

# %%
# reseting index of dataframe 
Institute_Final = Institute_Final.reset_index(drop=True)

# %%
Institute_Final = Institute_Final.replace(to_replace='..', value = 0)

# %%
# Rename the columns 
Institute_Final.columns = ['Institute', 'Study_Mode', '2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017']

# %%
Institute_Final.dtypes
# Out:
# Institute     object
# Study_Mode    object
# 2000          object
# 2001          object
# 2002          object
# 2003          object
# 2004          object
# 2005          object
# 2006          object
# 2007          object
# 2008          object
# 2009          object
# 2010          object
# 2011          object
# 2012          object
# 2013          object
# 2014          object
# 2015          object
# 2016          object
# 2017          object
# dtype: object

# %%
Institute_Final= Institute_Final.drop(Institute_Final.index[172:187])

# %%
Institute_Final
# Out:
#                                              Institute  \
# 0                              Aided university sector
# 1
# 2
# 3
# 4                 National University of Ireland, Cork
# 5
# 6
# 7
# 8               National University of Ireland, Dublin
# 9
# 10
# 11
# 12              National University of Ireland, Galway
# 13
# 14
# 15
# 16                             Trinity College, Dublin
# 17
# 18
# 19
# 20            National University of Ireland, Maynooth
# 21
# 22
# 23
# 24                              Dublin City University
# 25
# 26
# 27
# 28                              University of Limerick
# 29
# 30
# 31
# 32                             Aided technology sector
# 33
# 34
# 35
# 36                      Dublin Institute of Technology
# 37
# 38
# 39
# 40                     Athlone Institute of Technology
# 41
# 42
# 43
# 44                     Institute of Technology, Carlow
# 45
# 46
# 47
# 48                        Cork Institute of Technology
# 49
# 50
# 51
# ...

# %%
#Institute_Final_1['univercity_name'] = Institute_Final_1['Institute'] + Institute_Final_1['Study_Mode']

# %%
#Institute_Final_1 = Institute_Final_1.drop(columns=['Institute', 'Study_Mode'])

# %%
#cols = list(Institute_Final_1.columns)
#cols = [cols[-1]] + cols[:-1]
#Institute_Final_1 = Institute_Final_1[cols]

# %%
a = Institute_Final['Institute']

# %%
 tmplist=[]
for x in Institute_Final['Institute']:
    if x == ' ':
        tmplist.append(y)
    else:
        y = x
        tmplist.append(' ')
print(tmplist)
# Out:
# [' ', 'Aided university sector', 'Aided university sector', 'Aided university sector', ' ', 'National University of Ireland, Cork', 'National University of Ireland, Cork', 'National University of Ireland, Cork', ' ', 'National University of Ireland, Dublin', 'National University of Ireland, Dublin', 'National University of Ireland, Dublin', ' ', 'National University of Ireland, Galway', 'National University of Ireland, Galway', 'National University of Ireland, Galway', ' ', 'Trinity College, Dublin', 'Trinity College, Dublin', 'Trinity College, Dublin', ' ', 'National University of Ireland, Maynooth', 'National University of Ireland, Maynooth', 'National University of Ireland, Maynooth', ' ', 'Dublin City University', 'Dublin City University', 'Dublin City University', ' ', 'University of Limerick', 'University of Limerick', 'University of Limerick', ' ', 'Aided technology sector', 'Aided technology sector', 'Aided technology sector', ' ', 'Dublin Institute of Technology', 'Dublin In
# ...

# %%
Institute_data = pd.DataFrame(tmplist)

# %%
enrolment_by_institute = pd.concat([Institute_Final, Institute_data], axis=1)

# %%
# Droping rows from dataframe 
enrolment_by_institute = enrolment_by_institute.drop([0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116,120,124,128,132,136,140,144,148,152,156,160,164,168], axis=0)

# %%
enrolment_by_institute = enrolment_by_institute.drop(['Institute'], axis=1)

# %%
enrolment_by_institute
# Out:
#                                             Study_Mode    2000    2001  \
# 1    Full-time Enrolments to Third Level Courses (N...       0       0
# 2    Part-time Enrolments to Third Level Courses (N...       0       0
# 3             Entrants to Third Level Courses (Number)       0       0
# 5    Full-time Enrolments to Third Level Courses (N...   11122   11694
# 6    Part-time Enrolments to Third Level Courses (N...     772    1200
# 7             Entrants to Third Level Courses (Number)    2695    2681
# 9    Full-time Enrolments to Third Level Courses (N...   15088   14974
# 10   Part-time Enrolments to Third Level Courses (N...    3269    2936
# 11            Entrants to Third Level Courses (Number)    3414    3529
# 13   Full-time Enrolments to Third Level Courses (N...    8655    9267
# 14   Part-time Enrolments to Third Level Courses (N...    1126    1183
# 15            Entrants to Third Level Courses (Number)    2105    2349
# ...

# %%
# Rename the columns 
enrolment_by_institute.columns = ['Study_Mode', '2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','Institute']

# %%
enrolment_by_institute
# Out:
#                                             Study_Mode    2000    2001  \
# 1    Full-time Enrolments to Third Level Courses (N...       0       0
# 2    Part-time Enrolments to Third Level Courses (N...       0       0
# 3             Entrants to Third Level Courses (Number)       0       0
# 5    Full-time Enrolments to Third Level Courses (N...   11122   11694
# 6    Part-time Enrolments to Third Level Courses (N...     772    1200
# 7             Entrants to Third Level Courses (Number)    2695    2681
# 9    Full-time Enrolments to Third Level Courses (N...   15088   14974
# 10   Part-time Enrolments to Third Level Courses (N...    3269    2936
# 11            Entrants to Third Level Courses (Number)    3414    3529
# 13   Full-time Enrolments to Third Level Courses (N...    8655    9267
# 14   Part-time Enrolments to Third Level Courses (N...    1126    1183
# 15            Entrants to Third Level Courses (Number)    2105    2349
# ...

# %%
enrolment_by_institute.count()
# Out:
# Study_Mode    129
# 2000          129
# 2001          129
# 2002          129
# 2003          129
# 2004          129
# 2005          129
# 2006          129
# 2007          129
# 2008          129
# 2009          129
# 2010          129
# 2011          129
# 2012          129
# 2013          129
# 2014          129
# 2015          129
# 2016          129
# 2017          129
# Institute     129
# dtype: int64

# %%
enrolment_by_institute.to_csv(r'C:/Users/Imtiyaz/Desktop/Inernational_student_Dataset/student_enrillment_by_Institute_Final.csv' , index=False)

# %%
enrolment_by_institute.dtypes
# Out:
# Study_Mode    object
# 2000          object
# 2001          object
# 2002          object
# 2003          object
# 2004          object
# 2005          object
# 2006          object
# 2007          object
# 2008          object
# 2009          object
# 2010          object
# 2011          object
# 2012          object
# 2013          object
# 2014          object
# 2015          object
# 2016          object
# 2017          object
# Institute     object
# dtype: object

# %%
enrolment_by_institute =  enrolment_by_institute.astype({'Study_Mode':str,'2000':float,'2001':float,'2002':float,'2003':float,'2004':float,'2005':float,'2006':float,'2007':float,'2008':float,'2009':float,'2010':float,'2011':float,'2012':float,'2013':float,'2014':float,'2015':float,'2016':float,'2017':float,'Institute':str})
print(enrolment_by_institute.dtypes)
# Out:
# Study_Mode     object
# 2000          float64
# 2001          float64
# 2002          float64
# 2003          float64
# 2004          float64
# 2005          float64
# 2006          float64
# 2007          float64
# 2008          float64
# 2009          float64
# 2010          float64
# 2011          float64
# 2012          float64
# 2013          float64
# 2014          float64
# 2015          float64
# 2016          float64
# 2017          float64
# Institute      object
# dtype: object

# %%
plt.bar(enrolment_by_institute['Institute'], enrolment_by_institute['2000'], align='center')

plt.xlabel('Student Institute')
plt.ylabel('Count')
plt.title('Enrolment of Student in Ireand bt their origin and year')
plt.xticks(rotation=90)
plt.show()
